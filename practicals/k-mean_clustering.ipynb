# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# Step 1: import libraries
import numpy as np
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# %%
# Step 2:

# Step 3:Initialize KMeans model
# kmeans = KMeans(n_clusters=K, rondom_state=seed_value)

# Step 4: Fit the model
# kmeans.fit(data)

# Step 5: Get results
# All the other next steps found in the notes...

# Global Variables
divider = f"\n{"*" * 90}\n"

# Step 2: Prepare the data set
data = np.array([[1, 2], [1, 4], [1, 0], [10, 2], [10, 4], [10, 0]])

# %%
# Step 3: Initialize the K-Means Model
kmeans = KMeans(n_clusters=2, random_state=0)

# Step 4: Fit the Model to the Data
kmeans.fit(data)
# Out:
# KMeans(n_clusters=2, random_state=0)

# %%
# Step 5: Obtain Cluster Centroids and Labels
centroids = kmeans.cluster_centers_
labels = kmeans.labels_
print("=> Centroids:\n", centroids)
print(f"{divider}\n=> Labels:", labels)
# Out:
# => Centroids:
#  [[10.  2.]
#  [ 1.  2.]]
#
# ******************************************************************************************
#
# => Labels: [1 1 1 0 0 0]

# %%
# Step 6: Visualize Clusters and Centroids
colors = ["red" if label == 0 else "blue" for label in labels]
plt.scatter(data[:, 0], data[:, 1], c=colors)
plt.scatter(centroids[:, 0], centroids[:, 1], s=300, c="yellow", marker='*')
plt.title("K-Means Clustering Example")
plt.show()

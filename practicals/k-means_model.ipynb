# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
divider = f"\n{"*" * 90}\n"

data = {
    "YearsofExperience": [4.8, 6.2, 5.1, 3.9, 7.0, 6.5, 4.3, 5.7, 3.5, 6.8],
    "Monthly_Sales": [52000, 48000, 47000, 51000, 45000, 60000, 53000, 49000, 47000, 62000],
    "Project_completed": [3, 5, 4, 6, 2, 7, 4, 3, 5, 6]
}

df = pd.DataFrame(data)

# %%
# Step 3: Initialize the K-Means Model
kmeans = KMeans(n_clusters=2, random_state=0)

# Step 4: Fit the Model to the Data
kmeans.fit(df)
# Out:
# KMeans(n_clusters=2, random_state=0)

# %%
# Step 5: Obtain Cluster Centroids and Labels
centroids = kmeans.cluster_centers_
labels = kmeans.labels_
print("=> Centroids:\n", centroids)
print(f"{divider}\n=> Labels:", labels)
# Out:
# => Centroids:
#  [[6.6500e+00 6.1000e+04 6.5000e+00]
#  [5.0625e+00 4.9000e+04 4.0000e+00]]
#
# ******************************************************************************************
#
# => Labels: [1 1 1 1 1 0 1 1 1 0]

# %%
# Step 6: Visualize Clusters and Centroids
colors = ["red" if label == 0 else "blue" for label in labels]

plt.figure(figsize=(12, 6))

df = df.values

plt.scatter(df[:, 0], df[:, 1], c=colors)
plt.scatter(centroids[:, 0], centroids[:, 1], s=300, c="yellow", marker='*')
plt.title("K-Means Clustering Example", fontsize=16, fontweight="bold", pad=26)
plt.show()
